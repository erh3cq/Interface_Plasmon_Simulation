# %% [markdown]
# # Bulk plasmon Analysis
# Analysis of bulk plasmons
# - dielectric constants
# - Drude model

# %%
from __future__ import division
import numpy as np
from materials import Al, GB
from microscope import Microscope
from bulkMode import bulk_NR, bulk
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm

# %% [markdown]
# Set dimmensions

# %%
q_perpendicular = np.linspace(1E-3,1.5,200,endpoint=True)*1E10#np.linspace(-1.5,1.5,200,endpoint=True)*1E10#
E = np.arange(1,30,0.03)

q_perpendicular = q_perpendicular[:,np.newaxis]
E = E[np.newaxis,:]

# %% [markdown]
# Set materials

# %%
materials = [Al,GB()]#[Al,vac]#
for material in materials:
    print(material.name)
    print('n: ',material.n,'[e-/m^3]')
    material.set_Ep(type='Drude')
    print(material.E_p0)
    material.set_eps(E=E, q=q_perpendicular, type='Drude', multiple_eps=True)
    material.set_eps(E=E, q=q_perpendicular, type='Lindhard', multiple_eps=True)
    print('')
#print(materials[1].eps.shape)
#materials[1].eps = np.ones_like(materials[1].eps)*(4+0j)
#print(materials[1].eps)
# Out:
# Al
# n:  1.8117722802e+29 [e-/m^3]
# Setting E_p
# 16.0492781587
# Setting eps
# Setting eps
#
# GB
# n:  1.68381104041e+29 [e-/m^3]
# Setting E_p
# 15.2382902765
# Setting eps
# Setting eps

# %% [markdown]
# Set microscope

# %%
microscope = Microscope(keV=300)
microscope.print_parameters()
# Out:
# Microscope
#   keV :  300
#   gamma :  1.5870841487279843
#   beta2 :  0.6029912379261115
#   v :  232957531.351
#   T :  154304.780267
#   k0 :  3.19429261034e+12
#   resolution :  0.05
#   dispersion :  0.05
#   collection_angle :  0.002

# %% [markdown]
# # Plotting

# %% [markdown]
# dielectric funciton

# %%
fig, ax = plt.subplots(1, figsize=(20,10))
ax.plot(E[0,:],np.real(materials[0].eps[1,:]), '-k', label='Al real')
#ax.plot(E[0,:],np.imag(materials[0].eps[1,:]), '--k', label='Al imag')
ax.plot(E[0,:],np.real(materials[1].eps[1,:]), '-r', label='GB real')
#ax.plot(E[0,:],np.imag(materials[1].eps[1,:]), '--r', label='GB imag')
ax.set_xlabel('E [eV]')
ax.set_ylabel(r'$\epsilon(E)$')
#ax.set_xlim(xmin=3)
plt.autoscale(enable=True, axis='x', tight=True)
ax.legend()
plt.show()

# %%
#fig.savefig('C:/Users/erhog/Google Drive/Research/Simulations_electrodynamic/eps.jpg',
#            transparent=True, bbox_inches='tight', dpi=800)

# %%
fig, ax = plt.subplots(1, figsize=(20,10))
ax.plot(E[0,:],np.real(materials[0].eps[1,:]), '-k', label='Lindhard real')
ax.plot(E[0,:],np.imag(materials[0].eps[1,:]), '--k', label='Lindhard imag')
ax.plot(E[0,:],np.real(materials[0].eps_D[0,:]), '-r', label='Drude real')
ax.plot(E[0,:],np.imag(materials[0].eps_D[0,:]), '--r', label='Drude imag')
ax.set_xlabel('E [eV]')
ax.set_ylabel(r'$\epsilon(E)$')
#ax.set_xlim(xmin=3)
#ax.autoscale(enable=True, axis='y', tight=True)
ax.legend()
plt.show()

# %% [markdown]
# Bulk

# %%
f_bulk = bulk_NR(microscope, material=materials,
                   q_perpendicular=q_perpendicular, E=E, eps='Drude')

# %%
fig, ax = plt.subplots(2, figsize=(20,10), sharex=True)
img0 = ax[0].imshow(f_bulk, aspect='auto', origin='lower', norm=LogNorm(), cmap=plt.get_cmap('hot'),
             extent=(np.amin(E),np.amax(E), np.amin(q_perpendicular), np.amax(q_perpendicular)))
ax[0].set_ylabel(r'$q_{y} [m^-]$')
#fig.colorbar(mappable=img0, ax=ax[0])
ax[0].set_aspect('auto')

ax[1].plot(E[0,:],f_bulk.sum(axis=0))
ax[1].set_xlim(xmin=0)
plt.autoscale(enable=True, axis='x', tight=True)
ax[1].set_xlabel('E [eV]')
#plt.tight_layout(pad=0.001)
plt.show()

# %%
f_bulk = bulk_NR(microscope, material=materials,
                   q_perpendicular=q_perpendicular, E=E, eps='Lindhard')

# %%
fig, ax = plt.subplots(2, figsize=(20,10), sharex=True)
img0 = ax[0].imshow(f_bulk, aspect='auto', origin='lower', norm=LogNorm(), cmap=plt.get_cmap('hot'),
             extent=(np.amin(E),np.amax(E), np.amin(q_perpendicular), np.amax(q_perpendicular)))
ax[0].set_ylabel(r'$q_{y} [m^-]$')
#fig.colorbar(mappable=img0, ax=ax[0])
ax[0].set_aspect('auto')

ax[1].plot(E[0,:],f_bulk.sum(axis=0))
ax[1].set_xlim(xmin=0)
plt.autoscale(enable=True, axis='x', tight=True)
ax[1].set_xlabel('E [eV]')
#plt.tight_layout(pad=0.001)
plt.show()

# %%
#fig.savefig('C:/Users/erhog/Google Drive/Research/Simulations_electrodynamic/bulk.jpg',
#            transparent=True, bbox_inches='tight', dpi=800)
